# %%
from keras import *
from keras.layers import *
import numpy as np
import glob
import cv2
import os

os.environ["CUDA_VISIBLE_DEVICES"]="1"
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
def depthsep2d(f,conv):
    
    x = DepthwiseConv2D(3, padding='same', use_bias=False)(conv)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Convolution2D(f, (1, 1), strides=(1, 1), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    return x
        
def enc1(tensor,F = [12,12,48],times=4):
    
    for i in range(times):
        
        conv = depthsep2d(F[0],tensor)
        conv = depthsep2d(F[1],conv)
        conv = depthsep2d(F[2],conv)
        tensor = conv
        
    conv = Conv2D(F[2],(1,1),strides=2,activation = 'relu',padding = 'same')(conv)
    
    return conv
   
def attention_mod(conv):
    
    x = GlobalAveragePooling2D()(conv)
    x = Dense(1000, activation='relu')(x)
    x = Dense(192, activation='sigmoid')(x)
    x = Reshape((1,1,192))(x)
    fc = multiply([x,conv])

    
    return fc


def decode_conv(conv,f=48):
    
    conv = Convolution2D(f, (1, 1), padding='same')(conv)
    conv = BatchNormalization()(conv)
    conv = Activation('relu')(conv)
    
    return conv
    

    
def conv_cls(conv,num_classes = 5):
    
    conv = Convolution2D(num_classes, (3,3), padding='same',activation = 'softmax')(conv)

    
    return conv


def DFANet_Keras(H=512,W=512,num_classes = 5):

    input_map= Input(shape=(H,W,3))

    conv1 = Conv2D(8,(3,3),strides=1,activation = 'relu',padding = 'same')(input_map)

    enc1_2 = enc1(conv1,F = [12,12,48],times=3)

    enc1_3 = enc1(enc1_2,F = [24,24,96],times=6)

    enc1_4 = enc1(enc1_3,F = [48,48,192],times=3)

    fc1 = attention_mod(enc1_4)

    #=====================================
    conv_d1 = UpSampling2D(size=(4,4))(fc1)  

    c1 = concatenate([enc1_2,conv_d1],axis=3)

    enc2_2 = enc1(c1,F = [12,12,48],times=3)

    c2 = concatenate([enc2_2,enc1_3],axis=3)

    enc2_3 = enc1(c2,F = [24,24,96],times=3)

    c3 = concatenate([enc2_3,enc1_4],axis=3)

    enc2_4 = enc1(c3,F = [48,48,192],times=3)

    fc2 = attention_mod(enc2_4)
    #================================

    conv_d2 = UpSampling2D(size=(4,4))(fc2)

    c2_1 = concatenate([enc2_2,conv_d2],axis=3)

    enc3_2 = enc1(c2_1,F = [12,12,48],times=3)

    c2_2 = concatenate([enc2_3,enc3_2],axis=3)

    enc3_3 = enc1(c2_2,F = [24,24,96],times=3)

    c2_3 = concatenate([enc2_4,enc3_3],axis=3)

    enc3_4 = enc1(c2_3,F = [48,48,192],times=3)

    fc3 = attention_mod(enc3_4)

    #=======================================
    ## decoder section of paper

    ## from attention section 

    d1  = UpSampling2D(size=(4,4))(fc1)
    d1 = decode_conv(d1,f=48)

    d2  = UpSampling2D(size=(8,8))(fc2)
    d2 = decode_conv(d2,f=48)

    d3  = UpSampling2D(size=(16,16))(fc3)
    d3 = decode_conv(d3,f=48)



    ## from encoder section 
    d1_1  = UpSampling2D(size=(1,1))(enc1_2)
    d1_1 = decode_conv(d1_1,f=192)

    d2_1  = UpSampling2D(size=(2,2))(enc2_2)
    d2_1 = decode_conv(d2_1,f=192)

    d3_1 = UpSampling2D(size=(4,4))(enc3_2)
    d3_1 = decode_conv(d3_1,f=192)


    shallow = Add()([d1,d2,d3])
    shallow = decode_conv(shallow,f=192)


    final = Add()([shallow,d1_1,d2_1,d3_1])
    final = decode_conv(final,f=192)


    output = UpSampling2D(size=(2,2))(conv_cls(final,num_classes = num_classes))

    DFANet_model = Model(inputs = input_map,outputs = output)
    
    return DFANet_model
##=========================================================================

c = 5

DFANet_model = DFANet_Keras(H=512,W=512,num_classes = c)

DFANet_model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_51 (InputLayer)           (None, 288, 288, 3)  0
# __________________________________________________________________________________________________
# conv2d_3159 (Conv2D)            (None, 288, 288, 8)  224         input_51[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2771 (Depthwis (None, 288, 288, 8)  72          conv2d_3159[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5617 (Batch (None, 288, 288, 8)  32          depthwise_conv2d_2771[0][0]
# __________________________________________________________________________________________________
# activation_5617 (Activation)    (None, 288, 288, 8)  0           batch_normalization_5617[0][0]
# __________________________________________________________________________________________________
# conv2d_3160 (Conv2D)            (None, 288, 288, 12) 108         activation_5617[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5618 (Batch (None, 288, 288, 12) 48          conv2d_3160[0][0]
# __________________________________________________________________________________________________
# activation_5618 (Activation)    (None, 288, 288, 12) 0           batch_normalization_5618[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2772 (Depthwis (None, 288, 288, 12) 108         activation_5618[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5619 (Batch (None, 288, 288, 12) 48          depthwise_conv2d_2772[0][0]
# __________________________________________________________________________________________________
# activation_5619 (Activation)    (None, 288, 288, 12) 0           batch_normalization_5619[0][0]
# __________________________________________________________________________________________________
# conv2d_3161 (Conv2D)            (None, 288, 288, 12) 156         activation_5619[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5620 (Batch (None, 288, 288, 12) 48          conv2d_3161[0][0]
# __________________________________________________________________________________________________
# activation_5620 (Activation)    (None, 288, 288, 12) 0           batch_normalization_5620[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2773 (Depthwis (None, 288, 288, 12) 108         activation_5620[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5621 (Batch (None, 288, 288, 12) 48          depthwise_conv2d_2773[0][0]
# __________________________________________________________________________________________________
# activation_5621 (Activation)    (None, 288, 288, 12) 0           batch_normalization_5621[0][0]
# __________________________________________________________________________________________________
# conv2d_3162 (Conv2D)            (None, 288, 288, 48) 624         activation_5621[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5622 (Batch (None, 288, 288, 48) 192         conv2d_3162[0][0]
# __________________________________________________________________________________________________
# activation_5622 (Activation)    (None, 288, 288, 48) 0           batch_normalization_5622[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2774 (Depthwis (None, 288, 288, 48) 432         activation_5622[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5623 (Batch (None, 288, 288, 48) 192         depthwise_conv2d_2774[0][0]
# __________________________________________________________________________________________________
# activation_5623 (Activation)    (None, 288, 288, 48) 0           batch_normalization_5623[0][0]
# __________________________________________________________________________________________________
# conv2d_3163 (Conv2D)            (None, 288, 288, 12) 588         activation_5623[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5624 (Batch (None, 288, 288, 12) 48          conv2d_3163[0][0]
# __________________________________________________________________________________________________
# activation_5624 (Activation)    (None, 288, 288, 12) 0           batch_normalization_5624[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2775 (Depthwis (None, 288, 288, 12) 108         activation_5624[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5625 (Batch (None, 288, 288, 12) 48          depthwise_conv2d_2775[0][0]
# __________________________________________________________________________________________________
# activation_5625 (Activation)    (None, 288, 288, 12) 0           batch_normalization_5625[0][0]
# __________________________________________________________________________________________________
# conv2d_3164 (Conv2D)            (None, 288, 288, 12) 156         activation_5625[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5626 (Batch (None, 288, 288, 12) 48          conv2d_3164[0][0]
# __________________________________________________________________________________________________
# activation_5626 (Activation)    (None, 288, 288, 12) 0           batch_normalization_5626[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2776 (Depthwis (None, 288, 288, 12) 108         activation_5626[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5627 (Batch (None, 288, 288, 12) 48          depthwise_conv2d_2776[0][0]
# __________________________________________________________________________________________________
# activation_5627 (Activation)    (None, 288, 288, 12) 0           batch_normalization_5627[0][0]
# __________________________________________________________________________________________________
# conv2d_3165 (Conv2D)            (None, 288, 288, 48) 624         activation_5627[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5628 (Batch (None, 288, 288, 48) 192         conv2d_3165[0][0]
# __________________________________________________________________________________________________
# activation_5628 (Activation)    (None, 288, 288, 48) 0           batch_normalization_5628[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2777 (Depthwis (None, 288, 288, 48) 432         activation_5628[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5629 (Batch (None, 288, 288, 48) 192         depthwise_conv2d_2777[0][0]
# __________________________________________________________________________________________________
# activation_5629 (Activation)    (None, 288, 288, 48) 0           batch_normalization_5629[0][0]
# __________________________________________________________________________________________________
# conv2d_3166 (Conv2D)            (None, 288, 288, 12) 588         activation_5629[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5630 (Batch (None, 288, 288, 12) 48          conv2d_3166[0][0]
# __________________________________________________________________________________________________
# activation_5630 (Activation)    (None, 288, 288, 12) 0           batch_normalization_5630[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2778 (Depthwis (None, 288, 288, 12) 108         activation_5630[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5631 (Batch (None, 288, 288, 12) 48          depthwise_conv2d_2778[0][0]
# __________________________________________________________________________________________________
# activation_5631 (Activation)    (None, 288, 288, 12) 0           batch_normalization_5631[0][0]
# __________________________________________________________________________________________________
# conv2d_3167 (Conv2D)            (None, 288, 288, 12) 156         activation_5631[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5632 (Batch (None, 288, 288, 12) 48          conv2d_3167[0][0]
# __________________________________________________________________________________________________
# activation_5632 (Activation)    (None, 288, 288, 12) 0           batch_normalization_5632[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2779 (Depthwis (None, 288, 288, 12) 108         activation_5632[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5633 (Batch (None, 288, 288, 12) 48          depthwise_conv2d_2779[0][0]
# __________________________________________________________________________________________________
# activation_5633 (Activation)    (None, 288, 288, 12) 0           batch_normalization_5633[0][0]
# __________________________________________________________________________________________________
# conv2d_3168 (Conv2D)            (None, 288, 288, 48) 624         activation_5633[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5634 (Batch (None, 288, 288, 48) 192         conv2d_3168[0][0]
# __________________________________________________________________________________________________
# activation_5634 (Activation)    (None, 288, 288, 48) 0           batch_normalization_5634[0][0]
# __________________________________________________________________________________________________
# conv2d_3169 (Conv2D)            (None, 144, 144, 48) 2352        activation_5634[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2780 (Depthwis (None, 144, 144, 48) 432         conv2d_3169[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5635 (Batch (None, 144, 144, 48) 192         depthwise_conv2d_2780[0][0]
# __________________________________________________________________________________________________
# activation_5635 (Activation)    (None, 144, 144, 48) 0           batch_normalization_5635[0][0]
# __________________________________________________________________________________________________
# conv2d_3170 (Conv2D)            (None, 144, 144, 24) 1176        activation_5635[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5636 (Batch (None, 144, 144, 24) 96          conv2d_3170[0][0]
# __________________________________________________________________________________________________
# activation_5636 (Activation)    (None, 144, 144, 24) 0           batch_normalization_5636[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2781 (Depthwis (None, 144, 144, 24) 216         activation_5636[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5637 (Batch (None, 144, 144, 24) 96          depthwise_conv2d_2781[0][0]
# __________________________________________________________________________________________________
# activation_5637 (Activation)    (None, 144, 144, 24) 0           batch_normalization_5637[0][0]
# __________________________________________________________________________________________________
# conv2d_3171 (Conv2D)            (None, 144, 144, 24) 600         activation_5637[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5638 (Batch (None, 144, 144, 24) 96          conv2d_3171[0][0]
# __________________________________________________________________________________________________
# activation_5638 (Activation)    (None, 144, 144, 24) 0           batch_normalization_5638[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2782 (Depthwis (None, 144, 144, 24) 216         activation_5638[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5639 (Batch (None, 144, 144, 24) 96          depthwise_conv2d_2782[0][0]
# __________________________________________________________________________________________________
# activation_5639 (Activation)    (None, 144, 144, 24) 0           batch_normalization_5639[0][0]
# __________________________________________________________________________________________________
# conv2d_3172 (Conv2D)            (None, 144, 144, 96) 2400        activation_5639[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5640 (Batch (None, 144, 144, 96) 384         conv2d_3172[0][0]
# __________________________________________________________________________________________________
# activation_5640 (Activation)    (None, 144, 144, 96) 0           batch_normalization_5640[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2783 (Depthwis (None, 144, 144, 96) 864         activation_5640[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5641 (Batch (None, 144, 144, 96) 384         depthwise_conv2d_2783[0][0]
# __________________________________________________________________________________________________
# activation_5641 (Activation)    (None, 144, 144, 96) 0           batch_normalization_5641[0][0]
# __________________________________________________________________________________________________
# conv2d_3173 (Conv2D)            (None, 144, 144, 24) 2328        activation_5641[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5642 (Batch (None, 144, 144, 24) 96          conv2d_3173[0][0]
# __________________________________________________________________________________________________
# activation_5642 (Activation)    (None, 144, 144, 24) 0           batch_normalization_5642[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2784 (Depthwis (None, 144, 144, 24) 216         activation_5642[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5643 (Batch (None, 144, 144, 24) 96          depthwise_conv2d_2784[0][0]
# __________________________________________________________________________________________________
# activation_5643 (Activation)    (None, 144, 144, 24) 0           batch_normalization_5643[0][0]
# __________________________________________________________________________________________________
# conv2d_3174 (Conv2D)            (None, 144, 144, 24) 600         activation_5643[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5644 (Batch (None, 144, 144, 24) 96          conv2d_3174[0][0]
# __________________________________________________________________________________________________
# activation_5644 (Activation)    (None, 144, 144, 24) 0           batch_normalization_5644[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2785 (Depthwis (None, 144, 144, 24) 216         activation_5644[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5645 (Batch (None, 144, 144, 24) 96          depthwise_conv2d_2785[0][0]
# __________________________________________________________________________________________________
# activation_5645 (Activation)    (None, 144, 144, 24) 0           batch_normalization_5645[0][0]
# __________________________________________________________________________________________________
# conv2d_3175 (Conv2D)            (None, 144, 144, 96) 2400        activation_5645[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5646 (Batch (None, 144, 144, 96) 384         conv2d_3175[0][0]
# __________________________________________________________________________________________________
# activation_5646 (Activation)    (None, 144, 144, 96) 0           batch_normalization_5646[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2786 (Depthwis (None, 144, 144, 96) 864         activation_5646[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5647 (Batch (None, 144, 144, 96) 384         depthwise_conv2d_2786[0][0]
# __________________________________________________________________________________________________
# activation_5647 (Activation)    (None, 144, 144, 96) 0           batch_normalization_5647[0][0]
# __________________________________________________________________________________________________
# conv2d_3176 (Conv2D)            (None, 144, 144, 24) 2328        activation_5647[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5648 (Batch (None, 144, 144, 24) 96          conv2d_3176[0][0]
# __________________________________________________________________________________________________
# activation_5648 (Activation)    (None, 144, 144, 24) 0           batch_normalization_5648[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2787 (Depthwis (None, 144, 144, 24) 216         activation_5648[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5649 (Batch (None, 144, 144, 24) 96          depthwise_conv2d_2787[0][0]
# __________________________________________________________________________________________________
# activation_5649 (Activation)    (None, 144, 144, 24) 0           batch_normalization_5649[0][0]
# __________________________________________________________________________________________________
# conv2d_3177 (Conv2D)            (None, 144, 144, 24) 600         activation_5649[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5650 (Batch (None, 144, 144, 24) 96          conv2d_3177[0][0]
# __________________________________________________________________________________________________
# activation_5650 (Activation)    (None, 144, 144, 24) 0           batch_normalization_5650[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2788 (Depthwis (None, 144, 144, 24) 216         activation_5650[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5651 (Batch (None, 144, 144, 24) 96          depthwise_conv2d_2788[0][0]
# __________________________________________________________________________________________________
# activation_5651 (Activation)    (None, 144, 144, 24) 0           batch_normalization_5651[0][0]
# __________________________________________________________________________________________________
# conv2d_3178 (Conv2D)            (None, 144, 144, 96) 2400        activation_5651[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5652 (Batch (None, 144, 144, 96) 384         conv2d_3178[0][0]
# __________________________________________________________________________________________________
# activation_5652 (Activation)    (None, 144, 144, 96) 0           batch_normalization_5652[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2789 (Depthwis (None, 144, 144, 96) 864         activation_5652[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5653 (Batch (None, 144, 144, 96) 384         depthwise_conv2d_2789[0][0]
# __________________________________________________________________________________________________
# activation_5653 (Activation)    (None, 144, 144, 96) 0           batch_normalization_5653[0][0]
# __________________________________________________________________________________________________
# conv2d_3179 (Conv2D)            (None, 144, 144, 24) 2328        activation_5653[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5654 (Batch (None, 144, 144, 24) 96          conv2d_3179[0][0]
# __________________________________________________________________________________________________
# activation_5654 (Activation)    (None, 144, 144, 24) 0           batch_normalization_5654[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2790 (Depthwis (None, 144, 144, 24) 216         activation_5654[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5655 (Batch (None, 144, 144, 24) 96          depthwise_conv2d_2790[0][0]
# __________________________________________________________________________________________________
# activation_5655 (Activation)    (None, 144, 144, 24) 0           batch_normalization_5655[0][0]
# __________________________________________________________________________________________________
# conv2d_3180 (Conv2D)            (None, 144, 144, 24) 600         activation_5655[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5656 (Batch (None, 144, 144, 24) 96          conv2d_3180[0][0]
# __________________________________________________________________________________________________
# activation_5656 (Activation)    (None, 144, 144, 24) 0           batch_normalization_5656[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2791 (Depthwis (None, 144, 144, 24) 216         activation_5656[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5657 (Batch (None, 144, 144, 24) 96          depthwise_conv2d_2791[0][0]
# __________________________________________________________________________________________________
# activation_5657 (Activation)    (None, 144, 144, 24) 0           batch_normalization_5657[0][0]
# __________________________________________________________________________________________________
# conv2d_3181 (Conv2D)            (None, 144, 144, 96) 2400        activation_5657[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5658 (Batch (None, 144, 144, 96) 384         conv2d_3181[0][0]
# __________________________________________________________________________________________________
# activation_5658 (Activation)    (None, 144, 144, 96) 0           batch_normalization_5658[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2792 (Depthwis (None, 144, 144, 96) 864         activation_5658[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5659 (Batch (None, 144, 144, 96) 384         depthwise_conv2d_2792[0][0]
# __________________________________________________________________________________________________
# activation_5659 (Activation)    (None, 144, 144, 96) 0           batch_normalization_5659[0][0]
# __________________________________________________________________________________________________
# conv2d_3182 (Conv2D)            (None, 144, 144, 24) 2328        activation_5659[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5660 (Batch (None, 144, 144, 24) 96          conv2d_3182[0][0]
# __________________________________________________________________________________________________
# activation_5660 (Activation)    (None, 144, 144, 24) 0           batch_normalization_5660[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2793 (Depthwis (None, 144, 144, 24) 216         activation_5660[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5661 (Batch (None, 144, 144, 24) 96          depthwise_conv2d_2793[0][0]
# __________________________________________________________________________________________________
# activation_5661 (Activation)    (None, 144, 144, 24) 0           batch_normalization_5661[0][0]
# __________________________________________________________________________________________________
# conv2d_3183 (Conv2D)            (None, 144, 144, 24) 600         activation_5661[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5662 (Batch (None, 144, 144, 24) 96          conv2d_3183[0][0]
# __________________________________________________________________________________________________
# activation_5662 (Activation)    (None, 144, 144, 24) 0           batch_normalization_5662[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2794 (Depthwis (None, 144, 144, 24) 216         activation_5662[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5663 (Batch (None, 144, 144, 24) 96          depthwise_conv2d_2794[0][0]
# __________________________________________________________________________________________________
# activation_5663 (Activation)    (None, 144, 144, 24) 0           batch_normalization_5663[0][0]
# __________________________________________________________________________________________________
# conv2d_3184 (Conv2D)            (None, 144, 144, 96) 2400        activation_5663[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5664 (Batch (None, 144, 144, 96) 384         conv2d_3184[0][0]
# __________________________________________________________________________________________________
# activation_5664 (Activation)    (None, 144, 144, 96) 0           batch_normalization_5664[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2795 (Depthwis (None, 144, 144, 96) 864         activation_5664[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5665 (Batch (None, 144, 144, 96) 384         depthwise_conv2d_2795[0][0]
# __________________________________________________________________________________________________
# activation_5665 (Activation)    (None, 144, 144, 96) 0           batch_normalization_5665[0][0]
# __________________________________________________________________________________________________
# conv2d_3185 (Conv2D)            (None, 144, 144, 24) 2328        activation_5665[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5666 (Batch (None, 144, 144, 24) 96          conv2d_3185[0][0]
# __________________________________________________________________________________________________
# activation_5666 (Activation)    (None, 144, 144, 24) 0           batch_normalization_5666[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2796 (Depthwis (None, 144, 144, 24) 216         activation_5666[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5667 (Batch (None, 144, 144, 24) 96          depthwise_conv2d_2796[0][0]
# __________________________________________________________________________________________________
# activation_5667 (Activation)    (None, 144, 144, 24) 0           batch_normalization_5667[0][0]
# __________________________________________________________________________________________________
# conv2d_3186 (Conv2D)            (None, 144, 144, 24) 600         activation_5667[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5668 (Batch (None, 144, 144, 24) 96          conv2d_3186[0][0]
# __________________________________________________________________________________________________
# activation_5668 (Activation)    (None, 144, 144, 24) 0           batch_normalization_5668[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2797 (Depthwis (None, 144, 144, 24) 216         activation_5668[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5669 (Batch (None, 144, 144, 24) 96          depthwise_conv2d_2797[0][0]
# __________________________________________________________________________________________________
# activation_5669 (Activation)    (None, 144, 144, 24) 0           batch_normalization_5669[0][0]
# __________________________________________________________________________________________________
# conv2d_3187 (Conv2D)            (None, 144, 144, 96) 2400        activation_5669[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5670 (Batch (None, 144, 144, 96) 384         conv2d_3187[0][0]
# __________________________________________________________________________________________________
# activation_5670 (Activation)    (None, 144, 144, 96) 0           batch_normalization_5670[0][0]
# __________________________________________________________________________________________________
# conv2d_3188 (Conv2D)            (None, 72, 72, 96)   9312        activation_5670[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2798 (Depthwis (None, 72, 72, 96)   864         conv2d_3188[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5671 (Batch (None, 72, 72, 96)   384         depthwise_conv2d_2798[0][0]
# __________________________________________________________________________________________________
# activation_5671 (Activation)    (None, 72, 72, 96)   0           batch_normalization_5671[0][0]
# __________________________________________________________________________________________________
# conv2d_3189 (Conv2D)            (None, 72, 72, 48)   4656        activation_5671[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5672 (Batch (None, 72, 72, 48)   192         conv2d_3189[0][0]
# __________________________________________________________________________________________________
# activation_5672 (Activation)    (None, 72, 72, 48)   0           batch_normalization_5672[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2799 (Depthwis (None, 72, 72, 48)   432         activation_5672[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5673 (Batch (None, 72, 72, 48)   192         depthwise_conv2d_2799[0][0]
# __________________________________________________________________________________________________
# activation_5673 (Activation)    (None, 72, 72, 48)   0           batch_normalization_5673[0][0]
# __________________________________________________________________________________________________
# conv2d_3190 (Conv2D)            (None, 72, 72, 48)   2352        activation_5673[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5674 (Batch (None, 72, 72, 48)   192         conv2d_3190[0][0]
# __________________________________________________________________________________________________
# activation_5674 (Activation)    (None, 72, 72, 48)   0           batch_normalization_5674[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2800 (Depthwis (None, 72, 72, 48)   432         activation_5674[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5675 (Batch (None, 72, 72, 48)   192         depthwise_conv2d_2800[0][0]
# __________________________________________________________________________________________________
# activation_5675 (Activation)    (None, 72, 72, 48)   0           batch_normalization_5675[0][0]
# __________________________________________________________________________________________________
# conv2d_3191 (Conv2D)            (None, 72, 72, 192)  9408        activation_5675[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5676 (Batch (None, 72, 72, 192)  768         conv2d_3191[0][0]
# __________________________________________________________________________________________________
# activation_5676 (Activation)    (None, 72, 72, 192)  0           batch_normalization_5676[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2801 (Depthwis (None, 72, 72, 192)  1728        activation_5676[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5677 (Batch (None, 72, 72, 192)  768         depthwise_conv2d_2801[0][0]
# __________________________________________________________________________________________________
# activation_5677 (Activation)    (None, 72, 72, 192)  0           batch_normalization_5677[0][0]
# __________________________________________________________________________________________________
# conv2d_3192 (Conv2D)            (None, 72, 72, 48)   9264        activation_5677[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5678 (Batch (None, 72, 72, 48)   192         conv2d_3192[0][0]
# __________________________________________________________________________________________________
# activation_5678 (Activation)    (None, 72, 72, 48)   0           batch_normalization_5678[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2802 (Depthwis (None, 72, 72, 48)   432         activation_5678[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5679 (Batch (None, 72, 72, 48)   192         depthwise_conv2d_2802[0][0]
# __________________________________________________________________________________________________
# activation_5679 (Activation)    (None, 72, 72, 48)   0           batch_normalization_5679[0][0]
# __________________________________________________________________________________________________
# conv2d_3193 (Conv2D)            (None, 72, 72, 48)   2352        activation_5679[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5680 (Batch (None, 72, 72, 48)   192         conv2d_3193[0][0]
# __________________________________________________________________________________________________
# activation_5680 (Activation)    (None, 72, 72, 48)   0           batch_normalization_5680[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2803 (Depthwis (None, 72, 72, 48)   432         activation_5680[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5681 (Batch (None, 72, 72, 48)   192         depthwise_conv2d_2803[0][0]
# __________________________________________________________________________________________________
# activation_5681 (Activation)    (None, 72, 72, 48)   0           batch_normalization_5681[0][0]
# __________________________________________________________________________________________________
# conv2d_3194 (Conv2D)            (None, 72, 72, 192)  9408        activation_5681[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5682 (Batch (None, 72, 72, 192)  768         conv2d_3194[0][0]
# __________________________________________________________________________________________________
# activation_5682 (Activation)    (None, 72, 72, 192)  0           batch_normalization_5682[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2804 (Depthwis (None, 72, 72, 192)  1728        activation_5682[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5683 (Batch (None, 72, 72, 192)  768         depthwise_conv2d_2804[0][0]
# __________________________________________________________________________________________________
# activation_5683 (Activation)    (None, 72, 72, 192)  0           batch_normalization_5683[0][0]
# __________________________________________________________________________________________________
# conv2d_3195 (Conv2D)            (None, 72, 72, 48)   9264        activation_5683[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5684 (Batch (None, 72, 72, 48)   192         conv2d_3195[0][0]
# __________________________________________________________________________________________________
# activation_5684 (Activation)    (None, 72, 72, 48)   0           batch_normalization_5684[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2805 (Depthwis (None, 72, 72, 48)   432         activation_5684[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5685 (Batch (None, 72, 72, 48)   192         depthwise_conv2d_2805[0][0]
# __________________________________________________________________________________________________
# activation_5685 (Activation)    (None, 72, 72, 48)   0           batch_normalization_5685[0][0]
# __________________________________________________________________________________________________
# conv2d_3196 (Conv2D)            (None, 72, 72, 48)   2352        activation_5685[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5686 (Batch (None, 72, 72, 48)   192         conv2d_3196[0][0]
# __________________________________________________________________________________________________
# activation_5686 (Activation)    (None, 72, 72, 48)   0           batch_normalization_5686[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2806 (Depthwis (None, 72, 72, 48)   432         activation_5686[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5687 (Batch (None, 72, 72, 48)   192         depthwise_conv2d_2806[0][0]
# __________________________________________________________________________________________________
# activation_5687 (Activation)    (None, 72, 72, 48)   0           batch_normalization_5687[0][0]
# __________________________________________________________________________________________________
# conv2d_3197 (Conv2D)            (None, 72, 72, 192)  9408        activation_5687[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5688 (Batch (None, 72, 72, 192)  768         conv2d_3197[0][0]
# __________________________________________________________________________________________________
# activation_5688 (Activation)    (None, 72, 72, 192)  0           batch_normalization_5688[0][0]
# __________________________________________________________________________________________________
# conv2d_3198 (Conv2D)            (None, 36, 36, 192)  37056       activation_5688[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_79 (Gl (None, 192)          0           conv2d_3198[0][0]
# __________________________________________________________________________________________________
# dense_157 (Dense)               (None, 1000)         193000      global_average_pooling2d_79[0][0]
# __________________________________________________________________________________________________
# dense_158 (Dense)               (None, 192)          192192      dense_157[0][0]
# __________________________________________________________________________________________________
# reshape_77 (Reshape)            (None, 1, 1, 192)    0           dense_158[0][0]
# __________________________________________________________________________________________________
# multiply_76 (Multiply)          (None, 36, 36, 192)  0           reshape_77[0][0]
#                                                                  conv2d_3198[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_141 (UpSampling2D (None, 144, 144, 192 0           multiply_76[0][0]
# __________________________________________________________________________________________________
# concatenate_144 (Concatenate)   (None, 144, 144, 240 0           conv2d_3169[0][0]
#                                                                  up_sampling2d_141[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2807 (Depthwis (None, 144, 144, 240 2160        concatenate_144[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5689 (Batch (None, 144, 144, 240 960         depthwise_conv2d_2807[0][0]
# __________________________________________________________________________________________________
# activation_5689 (Activation)    (None, 144, 144, 240 0           batch_normalization_5689[0][0]
# __________________________________________________________________________________________________
# conv2d_3199 (Conv2D)            (None, 144, 144, 12) 2892        activation_5689[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5690 (Batch (None, 144, 144, 12) 48          conv2d_3199[0][0]
# __________________________________________________________________________________________________
# activation_5690 (Activation)    (None, 144, 144, 12) 0           batch_normalization_5690[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2808 (Depthwis (None, 144, 144, 12) 108         activation_5690[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5691 (Batch (None, 144, 144, 12) 48          depthwise_conv2d_2808[0][0]
# __________________________________________________________________________________________________
# activation_5691 (Activation)    (None, 144, 144, 12) 0           batch_normalization_5691[0][0]
# __________________________________________________________________________________________________
# conv2d_3200 (Conv2D)            (None, 144, 144, 12) 156         activation_5691[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5692 (Batch (None, 144, 144, 12) 48          conv2d_3200[0][0]
# __________________________________________________________________________________________________
# activation_5692 (Activation)    (None, 144, 144, 12) 0           batch_normalization_5692[0][0]
# ...
# __________________________________________________________________________________________________
# depthwise_conv2d_2855 (Depthwis (None, 18, 18, 192)  1728        activation_5784[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5785 (Batch (None, 18, 18, 192)  768         depthwise_conv2d_2855[0][0]
# __________________________________________________________________________________________________
# activation_5785 (Activation)    (None, 18, 18, 192)  0           batch_normalization_5785[0][0]
# __________________________________________________________________________________________________
# conv2d_3252 (Conv2D)            (None, 18, 18, 48)   9264        activation_5785[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5786 (Batch (None, 18, 18, 48)   192         conv2d_3252[0][0]
# __________________________________________________________________________________________________
# activation_5786 (Activation)    (None, 18, 18, 48)   0           batch_normalization_5786[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2856 (Depthwis (None, 18, 18, 48)   432         activation_5786[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5787 (Batch (None, 18, 18, 48)   192         depthwise_conv2d_2856[0][0]
# __________________________________________________________________________________________________
# activation_5787 (Activation)    (None, 18, 18, 48)   0           batch_normalization_5787[0][0]
# __________________________________________________________________________________________________
# conv2d_3253 (Conv2D)            (None, 18, 18, 48)   2352        activation_5787[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5788 (Batch (None, 18, 18, 48)   192         conv2d_3253[0][0]
# __________________________________________________________________________________________________
# activation_5788 (Activation)    (None, 18, 18, 48)   0           batch_normalization_5788[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2857 (Depthwis (None, 18, 18, 48)   432         activation_5788[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5789 (Batch (None, 18, 18, 48)   192         depthwise_conv2d_2857[0][0]
# __________________________________________________________________________________________________
# activation_5789 (Activation)    (None, 18, 18, 48)   0           batch_normalization_5789[0][0]
# __________________________________________________________________________________________________
# conv2d_3254 (Conv2D)            (None, 18, 18, 192)  9408        activation_5789[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5790 (Batch (None, 18, 18, 192)  768         conv2d_3254[0][0]
# __________________________________________________________________________________________________
# activation_5790 (Activation)    (None, 18, 18, 192)  0           batch_normalization_5790[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2858 (Depthwis (None, 18, 18, 192)  1728        activation_5790[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5791 (Batch (None, 18, 18, 192)  768         depthwise_conv2d_2858[0][0]
# __________________________________________________________________________________________________
# activation_5791 (Activation)    (None, 18, 18, 192)  0           batch_normalization_5791[0][0]
# __________________________________________________________________________________________________
# conv2d_3255 (Conv2D)            (None, 18, 18, 48)   9264        activation_5791[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5792 (Batch (None, 18, 18, 48)   192         conv2d_3255[0][0]
# __________________________________________________________________________________________________
# activation_5792 (Activation)    (None, 18, 18, 48)   0           batch_normalization_5792[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2859 (Depthwis (None, 18, 18, 48)   432         activation_5792[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5793 (Batch (None, 18, 18, 48)   192         depthwise_conv2d_2859[0][0]
# __________________________________________________________________________________________________
# activation_5793 (Activation)    (None, 18, 18, 48)   0           batch_normalization_5793[0][0]
# __________________________________________________________________________________________________
# conv2d_3256 (Conv2D)            (None, 18, 18, 48)   2352        activation_5793[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5794 (Batch (None, 18, 18, 48)   192         conv2d_3256[0][0]
# __________________________________________________________________________________________________
# activation_5794 (Activation)    (None, 18, 18, 48)   0           batch_normalization_5794[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2860 (Depthwis (None, 18, 18, 48)   432         activation_5794[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5795 (Batch (None, 18, 18, 48)   192         depthwise_conv2d_2860[0][0]
# __________________________________________________________________________________________________
# activation_5795 (Activation)    (None, 18, 18, 48)   0           batch_normalization_5795[0][0]
# __________________________________________________________________________________________________
# conv2d_3257 (Conv2D)            (None, 18, 18, 192)  9408        activation_5795[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5796 (Batch (None, 18, 18, 192)  768         conv2d_3257[0][0]
# __________________________________________________________________________________________________
# activation_5796 (Activation)    (None, 18, 18, 192)  0           batch_normalization_5796[0][0]
# __________________________________________________________________________________________________
# conv2d_3258 (Conv2D)            (None, 9, 9, 192)    37056       activation_5796[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_81 (Gl (None, 192)          0           conv2d_3258[0][0]
# __________________________________________________________________________________________________
# dense_161 (Dense)               (None, 1000)         193000      global_average_pooling2d_81[0][0]
# __________________________________________________________________________________________________
# dense_162 (Dense)               (None, 192)          192192      dense_161[0][0]
# __________________________________________________________________________________________________
# reshape_79 (Reshape)            (None, 1, 1, 192)    0           dense_162[0][0]
# __________________________________________________________________________________________________
# multiply_78 (Multiply)          (None, 9, 9, 192)    0           reshape_79[0][0]
#                                                                  conv2d_3258[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_143 (UpSampling2D (None, 144, 144, 192 0           multiply_76[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_144 (UpSampling2D (None, 144, 144, 192 0           multiply_77[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_145 (UpSampling2D (None, 144, 144, 192 0           multiply_78[0][0]
# __________________________________________________________________________________________________
# conv2d_3259 (Conv2D)            (None, 144, 144, 48) 9264        up_sampling2d_143[0][0]
# __________________________________________________________________________________________________
# conv2d_3260 (Conv2D)            (None, 144, 144, 48) 9264        up_sampling2d_144[0][0]
# __________________________________________________________________________________________________
# conv2d_3261 (Conv2D)            (None, 144, 144, 48) 9264        up_sampling2d_145[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5797 (Batch (None, 144, 144, 48) 192         conv2d_3259[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5798 (Batch (None, 144, 144, 48) 192         conv2d_3260[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5799 (Batch (None, 144, 144, 48) 192         conv2d_3261[0][0]
# __________________________________________________________________________________________________
# activation_5797 (Activation)    (None, 144, 144, 48) 0           batch_normalization_5797[0][0]
# __________________________________________________________________________________________________
# activation_5798 (Activation)    (None, 144, 144, 48) 0           batch_normalization_5798[0][0]
# __________________________________________________________________________________________________
# activation_5799 (Activation)    (None, 144, 144, 48) 0           batch_normalization_5799[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 144, 144, 48) 0           activation_5797[0][0]
#                                                                  activation_5798[0][0]
#                                                                  activation_5799[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_146 (UpSampling2D (None, 144, 144, 48) 0           conv2d_3169[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_147 (UpSampling2D (None, 144, 144, 48) 0           conv2d_3208[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_148 (UpSampling2D (None, 144, 144, 48) 0           conv2d_3238[0][0]
# __________________________________________________________________________________________________
# conv2d_3265 (Conv2D)            (None, 144, 144, 192 9408        add_19[0][0]
# __________________________________________________________________________________________________
# conv2d_3262 (Conv2D)            (None, 144, 144, 192 9408        up_sampling2d_146[0][0]
# __________________________________________________________________________________________________
# conv2d_3263 (Conv2D)            (None, 144, 144, 192 9408        up_sampling2d_147[0][0]
# __________________________________________________________________________________________________
# conv2d_3264 (Conv2D)            (None, 144, 144, 192 9408        up_sampling2d_148[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5803 (Batch (None, 144, 144, 192 768         conv2d_3265[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5800 (Batch (None, 144, 144, 192 768         conv2d_3262[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5801 (Batch (None, 144, 144, 192 768         conv2d_3263[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5802 (Batch (None, 144, 144, 192 768         conv2d_3264[0][0]
# __________________________________________________________________________________________________
# activation_5803 (Activation)    (None, 144, 144, 192 0           batch_normalization_5803[0][0]
# __________________________________________________________________________________________________
# activation_5800 (Activation)    (None, 144, 144, 192 0           batch_normalization_5800[0][0]
# __________________________________________________________________________________________________
# activation_5801 (Activation)    (None, 144, 144, 192 0           batch_normalization_5801[0][0]
# __________________________________________________________________________________________________
# activation_5802 (Activation)    (None, 144, 144, 192 0           batch_normalization_5802[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 144, 144, 192 0           activation_5803[0][0]
#                                                                  activation_5800[0][0]
#                                                                  activation_5801[0][0]
#                                                                  activation_5802[0][0]
# __________________________________________________________________________________________________
# conv2d_3266 (Conv2D)            (None, 144, 144, 192 37056       add_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5804 (Batch (None, 144, 144, 192 768         conv2d_3266[0][0]
# __________________________________________________________________________________________________
# activation_5804 (Activation)    (None, 144, 144, 192 0           batch_normalization_5804[0][0]
# __________________________________________________________________________________________________
# conv2d_3267 (Conv2D)            (None, 144, 144, 5)  8645        activation_5804[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_149 (UpSampling2D (None, 288, 288, 5)  0           conv2d_3267[0][0]
# ==================================================================================================
# Total params: 1,783,653
# Trainable params: 1,760,597
# Non-trainable params: 23,056
# __________________________________________________________________________________________________
